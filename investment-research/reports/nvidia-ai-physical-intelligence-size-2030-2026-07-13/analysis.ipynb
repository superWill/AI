# %% [markdown]
# ## tl;dr
#
# [COMPUTED] The 2030 scenarios produce $420B, $650B, and $950B of annual revenue. [INFERRED] Physical AI contributes 8%–18%; core AI infrastructure remains the dominant driver.

# %% [markdown]
# ## Context & Methods
#
# ### Key Assumptions
# The model separates core AI data center, physical-AI training/simulation, physical-AI edge, and gaming/other to avoid double counting.

# %%
from model import SCENARIOS, calculate
results = [calculate(s) for s in SCENARIOS]
results

# %% [markdown]
# ## Data
#
# Public anchors and assumptions are documented in `source-notes.md`; scenario calculations are in `model.py` and `scenario_query.sql`.

# %% [markdown]
# ## Results
#
# Run the code cell to reproduce revenue, physical-AI share, normalized net income, market capitalization, and price-per-share illustrations.

# %% [markdown]
# ## Takeaways
#
# [INFERRED] The current valuation requires something close to the base trajectory; physical AI is upside optionality rather than the principal 2030 justification.
